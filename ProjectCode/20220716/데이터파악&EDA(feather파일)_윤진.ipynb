# %% [markdown]
# ### ㅇ 목표
# : 신용카드 잔액을 갚지 않을 확률 예측
# ### • '채무 불이행' 기준
# : 120일 동안 미납 금액을 지불하지 않은 경우

# %% [markdown]
# ### • 평가 지표 : M=(G+D)/2
# G : 정규화된 지니 계수
# D : The default rate captured at 4%
#
#
# *성능측정에 사용되는 지니 계수 (https://yseon99.tistory.com/55)
#
# *negative(no defaults)클래스 - 1/20 다운샘플링 -> 평가 지표에서 20배 가중치 적용

# %% [markdown]
# ### • Features
#
# D_* = 연체 변수
# S_* = 지출 변수
# P_* = 지불 변수
# B_* = 균형 변수
# R_* = 위험 변수
#
# *변수는 익명화, 정규화되었음

# %% [markdown]
# #### * S_2
# train_data : 2017-03 ~ 2018-03
# test_data : 2018-04 ~ 2019-10

# %%
#pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_feather('train_data.ftr')

# %%
test = pd.read_feather('test_data.ftr')

# %%
with pd.option_context("display.min_rows", 6):
    display(train)
    display(test)
# Out:
#                                                customer_ID        S_2  \
# 0        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-03-09
# 1        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-04-07
# 2        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-05-28
# ...                                                    ...        ...
# 5531448  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea... 2018-01-06
# 5531449  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea... 2018-02-06
# 5531450  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea... 2018-03-14
#
#               P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# 0        0.938477  0.001734  0.008728  1.006836  0.009224  0.124023  0.008774
# 1        0.936523  0.005775  0.004925  1.000977  0.006153  0.126709  0.000798
# 2        0.954102  0.091492  0.021652  1.009766  0.006817  0.123962  0.007599
# ...           ...       ...       ...       ...       ...       ...       ...
# ...

# %%
print(list(train.columns))
# Out:
# ['customer_ID', 'S_2', 'P_2', 'D_39', 'B_1', 'B_2', 'R_1', 'S_3', 'D_41', 'B_3', 'D_42', 'D_43', 'D_44', 'B_4', 'D_45', 'B_5', 'R_2', 'D_46', 'D_47', 'D_48', 'D_49', 'B_6', 'B_7', 'B_8', 'D_50', 'D_51', 'B_9', 'R_3', 'D_52', 'P_3', 'B_10', 'D_53', 'S_5', 'B_11', 'S_6', 'D_54', 'R_4', 'S_7', 'B_12', 'S_8', 'D_55', 'D_56', 'B_13', 'R_5', 'D_58', 'S_9', 'B_14', 'D_59', 'D_60', 'D_61', 'B_15', 'S_11', 'D_62', 'D_63', 'D_64', 'D_65', 'B_16', 'B_17', 'B_18', 'B_19', 'D_66', 'B_20', 'D_68', 'S_12', 'R_6', 'S_13', 'B_21', 'D_69', 'B_22', 'D_70', 'D_71', 'D_72', 'S_15', 'B_23', 'D_73', 'P_4', 'D_74', 'D_75', 'D_76', 'B_24', 'R_7', 'D_77', 'B_25', 'B_26', 'D_78', 'D_79', 'R_8', 'R_9', 'S_16', 'D_80', 'R_10', 'R_11', 'B_27', 'D_81', 'D_82', 'S_17', 'R_12', 'B_28', 'R_13', 'D_83', 'R_14', 'R_15', 'D_84', 'R_16', 'B_29', 'B_30', 'S_18', 'D_86', 'D_87', 'R_17', 'R_18', 'D_88', 'B_31', 'S_19', 'R_19', 'B_32', 'S_20', 'R_20', 'R_21', 'B_33', 'D_89', 'R_22', 'R_23', 'D_91', 'D_92', 'D_93', 'D_94', 'R
# ...

# %%
train.info(max_cols=200, show_counts=True)

# 결측값이 다수 존재함을 확인할 수 있음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5531451 entries, 0 to 5531450
# Data columns (total 191 columns):
#  #    Column       Non-Null Count    Dtype
# ---   ------       --------------    -----
#  0    customer_ID  5531451 non-null  object
#  1    S_2          5531451 non-null  datetime64[ns]
#  2    P_2          5485466 non-null  float16
#  3    D_39         5531451 non-null  float16
#  4    B_1          5531451 non-null  float16
#  5    B_2          5529435 non-null  float16
#  6    R_1          5531451 non-null  float16
#  7    S_3          4510907 non-null  float16
#  8    D_41         5529435 non-null  float16
#  9    B_3          5529435 non-null  float16
#  10   D_42         791314 non-null   float16
#  11   D_43         3873055 non-null  float16
#  12   D_44         5257132 non-null  float16
#  13   B_4          5531451 non-null  float16
#  14   D_45         5529434 non-null  float16
#  15   B_5          5531451 non-null  float16
# ...

# %%
# 16->10진수 변환
train['customer_ID'] =\
train['customer_ID'].apply(lambda x: int(x[-16:],16)).astype('int64')

# %% [markdown]
# #### + 참고한 노트북
# https://www.kaggle.com/code/ambrosm/amex-eda-which-makes-sense
# https://www.kaggle.com/code/kellibelcher/amex-default-prediction-eda-lgbm-baseline
