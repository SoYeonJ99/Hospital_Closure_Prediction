# %% [markdown]
# ## 대회 주제
# 병원 재무 데이터를 기반으로 병원이 계속 영업할지, 폐업할지 여부를 예측.
# target variable: OC(open/close). 영업=1, 폐업=0

# %% [markdown]
# ## 변수의 의미
# inst_id - 각 파일에서의 병원 고유 번호
#
# OC – 영업/폐업 분류, 2018년 폐업은 2017년 폐업으로 간주함.
#
# sido – 병원의 광역 지역 정보
#
# sgg – 병원의 시군구 자료
#
# openDate – 병원 설립일
#
# bedCount - 병원이 갖추고 있는 병상의 수
#
# instkind – 병원, 의원, 요양병원, 한의원, 종합병원 등 병원의 종류
#
#  + 종합병원 : 입원환자 100명 이상 수용 가능
#
#  + 병원 : 입원 환자 30명 이상 100명 미만 수용 가능
#
#  + 의원 : 입원 환자 30명 이하 수용 가능
#
#  + 한방 병원(한의원) : 침술과 한약으로 치료하는 의료 기관.
#
#
#
# revenue1 – 매출액, 2017(회계년도)년 데이터를 의미함
#
# salescost1 – 매출원가, 2017(회계년도)년 데이터를 의미함
#
# sga1 - 판매비와 관리비, 2017(회계년도)년 데이터를 의미함
#
# salary1 – 급여, 2017(회계년도)년 데이터를 의미함
#
# noi1 – 영업외수익, 2017(회계년도)년 데이터를 의미함
#
# noe1 – 영업외비용, 2017(회계년도)년 데이터를 의미함
#
# Interest1 – 이자비용, 2017(회계년도)년 데이터를 의미함
#
# ctax1 – 법인세비용, 2017(회계년도)년 데이터를 의미함
#
# Profit1 – 당기순이익, 2017(회계년도)년 데이터를 의미함
#
# liquidAsset1 – 유동자산, 2017(회계년도)년 데이터를 의미함
#
# quickAsset1 – 당좌자산, 2017(회계년도)년 데이터를 의미함
#
# receivableS1 - 미수금(단기), 2017(회계년도)년 데이터를 의미함
#
# inventoryAsset1 – 재고자산, 2017(회계년도)년 데이터를 의미함
#
# nonCAsset1 – 비유동자산, 2017(회계년도)년 데이터를 의미함
#
# tanAsset1 – 유형자산, 2017(회계년도)년 데이터를 의미함
#
# OnonCAsset1 - 기타 비유동자산, 2017(회계년도)년 데이터를 의미함
#
# receivableL1 – 장기미수금, 2017(회계년도)년 데이터를 의미함
#
# debt1 – 부채총계, 2017(회계년도)년 데이터를 의미함
#
# liquidLiabilities1 – 유동부채, 2017(회계년도)년 데이터를 의미함
#
# shortLoan1 – 단기차입금, 2017(회계년도)년 데이터를 의미함
#
# NCLiabilities1 – 비유동부채, 2017(회계년도)년 데이터를 의미함
#
# longLoan1 – 장기차입금, 2017(회계년도)년 데이터를 의미함
#
# netAsset1 – 순자산총계, 2017(회계년도)년 데이터를 의미함
#
# surplus1 – 이익잉여금, 2017(회계년도)년 데이터를 의미함
#
#
#
# revenue2 – 매출액, 2016(회계년도)년 데이터를 의미함
#
# salescost2 – 매출원가, 2016(회계년도)년 데이터를 의미함
#
# sga2 - 판매비와 관리비, 2016(회계년도)년 데이터를 의미함
#
# salary2 – 급여, 2016(회계년도)년 데이터를 의미함
#
# noi2 – 영업외수익, 2016(회계년도)년 데이터를 의미함
#
# noe2 – 영업외비용, 2016(회계년도)년 데이터를 의미함
#
# interest2 – 이자비용, 2016(회계년도)년 데이터를 의미함
#
# ctax2 – 법인세비용, 2016(회계년도)년 데이터를 의미함
#
# profit2 – 당기순이익, 2016(회계년도)년 데이터를 의미함
#
# liquidAsset2 – 유동자산, 2016(회계년도)년 데이터를 의미함
#
# quickAsset2 – 당좌자산, 2016(회계년도)년 데이터를 의미함
#
# receivableS2 - 미수금(단기), 2016(회계년도)년 데이터를 의미함
#
# inventoryAsset2 – 재고자산, 2016(회계년도)년 데이터를 의미함
#
# nonCAsset2 – 비유동자산, 2016(회계년도)년 데이터를 의미함
#
# tanAsset2 – 유형자산, 2016(회계년도)년 데이터를 의미함
#
# OnonCAsset2 - 기타 비유동자산, 2016(회계년도)년 데이터를 의미함
#
# receivableL2 – 장기미수금, 2016(회계년도)년 데이터를 의미함
#
# Debt2 – 부채총계, 2016(회계년도)년 데이터를 의미함
#
# liquidLiabilities2 – 유동부채, 2016(회계년도)년 데이터를 의미함
#
# shortLoan2 – 단기차입금, 2016(회계년도)년 데이터를 의미함
#
# NCLiabilities2 – 비유동부채, 2016(회계년도)년 데이터를 의미함
#
# longLoan2 – 장기차입금, 2016(회계년도)년 데이터를 의미함
#
# netAsset2 – 순자산총계, 2016(회계년도)년 데이터를 의미함
#
# surplus2 – 이익잉여금, 2016(회계년도)년 데이터를 의미함
#
# employee1 – 고용한 총 직원의 수, 2017(회계년도)년 데이터를 의미함
#
# employee2 – 고용한 총 직원의 수, 2016(회계년도)년 데이터를 의미함
#
# ownerChange – 대표자의 변동

# %% [markdown]
# - **크게 [병원 기본 정보] + [2017년 재무 정보] + [2016년 재무 정보]로 이루어진 데이터임**

# %% [markdown]
# ## 재무제표 용어
# - 매출총이익: 매출액(revenue) - 매출원가(salecost)
#
#
# - 영업외 수익/비용(noi/noe): 이자수익과 손실, 배당금, 임대료 수익, 주식투자로 얻은 수익과 손실 등 영업과 관련되지 않는 부문에서 발생한 수익과 비용.
#
#
# - 당기순이익(profit): 해당 기간 동안 기업이 창출한 순이익.
#  > 매출액: 기업이 일정기간 판매한 총량
#
#  > (매출)총이익: 매출액 - 매출원가
#
#  > 영업이익: 총이익 - 판매비·관리비
#
#  > 경상이익: 영업이익 + (영업외수익 - 영업외비용)
#
#  > (당기)순이익: 경상이익 + (특별이익 - 특별손실) - 법인세
#                 = 매출액 - 매출원가 - 판매비·관리비 + (영업외수익 - 영업외비용) + (특별이익 - 특별손실) - 법인세
#
#
# - 유동자산(liquidAsset): **비유동자산과 반대되는 개념**. 현금 및 비교적 단기(1년 내)에 회수 또는 판매에 의하여 현금화할 수 있는 재화. **당좌자산과 재고자산으로 구분.**
#
#
# - 당좌자산(quickAsset): 현금화가 매우 신속하게 이뤄질 수 있는 자산
#
#
# - 재고자산(inventoryAsset): 복잡한 제조과정이나 판매과정을 거쳐야만 현금화가 가능한 자산
#
#
# - 비유동자산(nonCAsset): 1년 이상의 장기간에 걸쳐 기업 내에 체류하는 자산. (판매 또는 처분을 목적으로 하지 않고 비교적 장기간에 걸쳐 영업활동에 사용하고자 취득한 각종 자산.) 크게 투자자산, **유형자산**, 무형자산, **기타비유동자산**으로 구분.
#
#
# - 유형자산(tanAsset): 경영 수단으로 반복 사용되며 구체적인 형태를 갖춘 고정자산. 토지, 건물, 기계장치, 구축물, 선박, 차량운반구, 공구와 기구, 비품, 건설중인 자산 등
#
#
# - 유동부채(liquidLiabilities): 1년이내에 상환해야 하는 채무. 외상매입금과 지급어음, 금전채무, 일반적으로 기한 1년 이내의 **단기차입금**, 미지급금, 미지급비용, 선수금, 예수금, 충당금 등이 속한다. 유동부채는 지급기한이 짧기 때문에 **기업이 지급능력을 보유하기 위해서는 유동부채보다 더 많은 유동자산을 보유하고 있어야만 한다.**
#
#
# - 단기차입금(shortLoan): 결산일 또는 그 다음날을 기준으로 지급 기한이 1년 이내인 차입금. 운전자금(기업이 임금이나 이자의 지불 또는 원재료의 매입 등 경상적 활동에 필요로 하는 자금)
#
#
# - 비유동부채(NCLiabilities): 일반적으로 지불 기한이 1년을 초과하는 부채. 사채, 임대보증금, 장기차입금, 퇴직급여충당부채, 이연법인세부채, 장기매입채무 등으로 구분.
#
#
# - 순자산(자기자산)(netAsset): 총자산으로부터 부채를 뺀것. 즉 자본금, 자본준비금, 이익준비금, **이익잉여금** 등의 합계. 출자의 원천에 따라 출자자에 귀속되는 자본 부분.
#
#
# - 이익잉여금(surplus): 기업의 경상적인 영업활동, 고정자산의 처분, 그 밖의 자산의 처분 및 기타 임시적인 손익거래에서 생긴 결과로서 주주에게 배당금으로 지급하거나 자본으로 대체되지 않고 남아있는 부분
#
#
# - 유동·비유동의 구분 표시는 자산과 부채 모두에 대하여 적용하는데, 이는 재무제표 이용자로 하여금 정상영업주기 또는 12개월 이내에 실현될 것으로 예상되는 자산과 동 기간 내에 결제 기일이 도래하는 부채를 확인할 수 있게 하여, 향후 미래현금흐름에 대한 예측 및 재무건전성이나 운전자본을 검토하는 데 유용한 정보를 제공하기 위함이다.
#
#
# 출처: 네이버 지식백과

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# - **의미의 상하 관계가 존재하는 변수 간에는 상관관계를 주의 깊게 살펴볼 필요가 있어보임**

# %% [markdown]
# ### 변수 구분
# **손익계산서:**
# 기간별 사업 내역 (수입/지출 내역)
# - revenue(매출액)
# - salescost(매출원가)
# - sga(판매비와 관리비)
# - salary(급여)
# - noi(영업외수익)
# - noe(영업외비용)
# - Interest(이자비용)
# - ctax(법인세비용)
# - Profit(당기순이익)
#
#
# **대차대조표:**
# 기간말 현재 자산/금전조달 상황. (내 돈과 빌린 돈)
# - liquidAsset(유동자산) ~ surplus(이익잉여금)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pd.read_csv('D:/숙탯 2기/2022-여름-캐글/9565_hospital_data/train.csv')
test_df = pd.read_csv('D:/숙탯 2기/2022-여름-캐글/9565_hospital_data/test.csv')

# %% [markdown]
# ## 1) 데이터 기본 정보

# %%
train_df.head()
# Out:
#    inst_id    OC       sido  sgg  openDate  bedCount          instkind  \
# 0        1  open  choongnam   73  20071228     175.0  nursing_hospital
# 1        3  open  gyeongnam   32  19970401     410.0  general_hospital
# 2        4  open   gyeonggi   89  20161228     468.0  nursing_hospital
# 3        7  open    incheon  141  20000814     353.0  general_hospital
# 4        9  open  gyeongnam   32  20050901     196.0  general_hospital
#
#        revenue1   salescost1          sga1  ...         debt2  \
# 0  4.217530e+09          0.0  3.961135e+09  ...  7.589937e+08
# 1           NaN          NaN           NaN  ...           NaN
# 2  1.004522e+09  515483669.0  4.472197e+08  ...  0.000000e+00
# 3  7.250734e+10          0.0  7.067740e+10  ...  3.775501e+10
# 4  4.904354e+10          0.0  4.765605e+10  ...  5.143259e+10
#
#    liquidLiabilities2    shortLoan2  NCLiabilities2     longLoan2  \
# 0        2.228769e+08  0.000000e+00    5.361169e+08  3.900000e+08
# ...

# %%
train_df.shape
# Out:
# (301, 58)

# %%
test_df.head()
# Out:
#    inst_id  OC     sido  sgg    openDate  bedCount          instkind  \
# 0        2 NaN  incheon  139  19981125.0     300.0  general_hospital
# 1        5 NaN     jeju  149  20160309.0      44.0          hospital
# 2        6 NaN  jeonnam  103  19890427.0     276.0  general_hospital
# 3        8 NaN    busan   71  20100226.0     363.0  general_hospital
# 4       10 NaN  jeonbuk   26  20040604.0     213.0  general_hospital
#
#        revenue1    salescost1          sga1  ...         debt2  \
# 0  6.682486e+10  0.000000e+00  6.565709e+10  ...  5.540643e+10
# 1  3.495758e+10  0.000000e+00  3.259270e+10  ...  6.730838e+10
# 2  2.326031e+10  2.542571e+09  2.308749e+10  ...  0.000000e+00
# 3  0.000000e+00  0.000000e+00  0.000000e+00  ...  1.211517e+10
# 4  5.037025e+10  0.000000e+00  4.855803e+10  ...  4.395973e+10
#
#    liquidLiabilities2    shortLoan2  NCLiabilities2     longLoan2  \
# 0        5.068443e+10  3.714334e+10    4.720000e+09  4.690000e+09
# ...

# %%
test_df.shape
# Out:
# (127, 58)

# %%
train_df['inst_id'].duplicated().sum(), test_df['inst_id'].duplicated().sum()
# Out:
# (0, 0)

# %% [markdown]
# - **중복된 병원 id 없음**

# %%
train_df.OC.value_counts()
# Out:
# open      286
#  close     15
# Name: OC, dtype: int64

# %%
plt.bar(['open', 'close'], train_df.OC.value_counts())
plt.show()

# %% [markdown]
# - **레이블 간의 비율이 매우 불균형**하므로 accuracy는 성능 평가 지표로 부적절한데, 대회에서 정한 평가 지표가 accuracy이므로 전처리 단계에서 불균형 문제를 반드시 해결해야 함. **데이터셋이 크지 않으므로 오버샘플링 고려.**

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 58 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   inst_id             301 non-null    int64
#  1   OC                  301 non-null    object
#  2   sido                301 non-null    object
#  3   sgg                 301 non-null    int64
#  4   openDate            301 non-null    int64
#  5   bedCount            296 non-null    float64
#  6   instkind            300 non-null    object
#  7   revenue1            293 non-null    float64
#  8   salescost1          293 non-null    float64
#  9   sga1                293 non-null    float64
#  10  salary1             293 non-null    float64
#  11  noi1                293 non-null    float64
#  12  noe1                293 non-null    float64
#  13  interest1           293 non-null    float64
#  14  ctax1               293 non-null    float64
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 58 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   inst_id             127 non-null    int64
#  1   OC                  0 non-null      float64
#  2   sido                127 non-null    object
#  3   sgg                 127 non-null    int64
#  4   openDate            126 non-null    float64
#  5   bedCount            119 non-null    float64
#  6   instkind            125 non-null    object
#  7   revenue1            125 non-null    float64
#  8   salescost1          125 non-null    float64
#  9   sga1                125 non-null    float64
#  10  salary1             125 non-null    float64
#  11  noi1                125 non-null    float64
#  12  noe1                125 non-null    float64
#  13  interest1           125 non-null    float64
#  14  ctax1               125 non-null    float64
# ...

# %% [markdown]
# - openDatetime: train data에서는 int, test data에서는 float

# %%
train_df.describe().transpose()
# Out:
#                     count          mean           std           min  \
# inst_id             301.0  2.190565e+02  1.212349e+02  1.000000e+00
# sgg                 301.0  8.103987e+01  5.096971e+01  1.000000e+00
# openDate            301.0  2.005013e+07  8.893815e+04  1.978012e+07
# bedCount            296.0  1.457095e+02  1.189239e+02  0.000000e+00
# revenue1            293.0  1.288175e+10  2.043543e+10  0.000000e+00
# salescost1          293.0  2.014903e+09  7.460271e+09  0.000000e+00
# sga1                293.0  1.033244e+10  1.493886e+10  0.000000e+00
# salary1             293.0  5.654115e+09  8.083343e+09  0.000000e+00
# noi1                293.0  2.696151e+08  8.023701e+08  0.000000e+00
# noe1                293.0  5.115870e+08  1.060379e+09  0.000000e+00
# interest1           293.0  1.868966e+08  2.738658e+08  0.000000e+00
# ctax1               293.0  7.847322e+07  2.486102e+08  0.000000e+00
# profit1             293.0  2.101700e+08  1.134673e+09 -4.696701e+09
# ...

# %%
test_df.describe().transpose()
# Out:
#                     count          mean           std           min  \
# inst_id             127.0  2.059055e+02  1.318018e+02  2.000000e+00
# OC                    0.0           NaN           NaN           NaN
# sgg                 127.0  9.585827e+01  5.268425e+01  6.000000e+00
# openDate            126.0  2.005085e+07  8.795815e+04  1.976041e+07
# bedCount            119.0  1.727899e+02  1.260245e+02  0.000000e+00
# revenue1            125.0  1.824446e+10  3.133530e+10  0.000000e+00
# salescost1          125.0  3.973321e+09  1.419948e+10  0.000000e+00
# sga1                125.0  1.340410e+10  2.054481e+10  0.000000e+00
# salary1             125.0  7.415084e+09  1.210043e+10  0.000000e+00
# noi1                125.0  5.175513e+08  1.193139e+09  0.000000e+00
# noe1                125.0  8.704307e+08  1.804461e+09  0.000000e+00
# interest1           125.0  3.168253e+08  4.587781e+08  0.000000e+00
# ctax1               125.0  1.148616e+08  3.089796e+08  0.000000e+00
# ...

# %% [markdown]
# - 금액 단위를 감안해도 표준편차가 매우 큰 열들의 경우 **이상치**가 존재할 것으로 예상

# %% [markdown]
# ## 2) feature

# %% [markdown]
# #### 시/도

# %%
plt.figure(figsize=(18,4))
sns.countplot(x="sido", data=train_df, hue="OC").set(title='train data')
plt.show()

# %%
train_df[['OC', 'sido']].groupby('sido').value_counts().unstack()
# Out:
# OC          close  open
# sido
# busan         1.0  25.0
# choongbuk     NaN  13.0
# choongnam     1.0  22.0
# daegu         NaN  14.0
# daejeon       NaN  13.0
# gangwon       NaN  10.0
# gwangju       NaN   2.0
# gyeongbuk     2.0  37.0
# gyeonggi      5.0  44.0
# gyeongnam     NaN  35.0
# incheon       NaN  10.0
# jeonbuk       2.0  16.0
# jeonnam       3.0  18.0
# sejong        NaN   1.0
# seoul         1.0  18.0
# ulsan         NaN   8.0

# %%
plt.figure(figsize=(16,4))
sns.countplot(x="sido", data=test_df).set(title='test data')
plt.show()

# %% [markdown]
# #### 병원 종류

# %%
plt.figure(figsize=(16,4))
sns.countplot(x="instkind", data=train_df, hue="OC").set(title='train data')
plt.show()

# %%
train_df[['OC', 'instkind']].groupby('instkind').value_counts().unstack()
# Out:
# OC                     close   open
# instkind
# clinic                   1.0   17.0
# dental_clinic            NaN    1.0
# general_hospital         1.0   36.0
# hospital                 5.0   83.0
# nursing_hospital         5.0  139.0
# traditional_clinic       1.0    3.0
# traditional_hospital     1.0    7.0

# %%
plt.figure(figsize=(16,4))
sns.countplot(x="instkind", data=test_df).set(title='test data')
plt.show()

# %% [markdown]
# #### bedCount 변수와 instkind 변수의 관계

# %%
train_df[['bedCount', 'instkind']].groupby('instkind').describe()
# Out:
#                      bedCount                                               \
#                         count        mean         std   min     25%    50%
# instkind
# clinic                   18.0    4.444444    8.548975   0.0    0.00    0.0
# dental_clinic             1.0    0.000000         NaN   0.0    0.00    0.0
# general_hospital         37.0  261.567568  105.566077  55.0  196.00  243.0
# hospital                 86.0   96.220930   65.063300  18.0   45.25   72.5
# nursing_hospital        144.0  172.340278  120.454684   0.0  110.00  153.5
# traditional_clinic        4.0    0.000000    0.000000   0.0    0.00    0.0
# traditional_hospital      6.0   46.666667   16.966634  28.0   33.25   44.0
#
#
#                          75%    max
# instkind
# clinic                  3.00   29.0
# dental_clinic           0.00    0.0
# general_hospital      306.00  545.0
# hospital              145.25  311.0
# nursing_hospital      194.50  656.0
# traditional_clinic      0.00    0.0
# ...

# %% [markdown]
# #### 대표자의 변동

# %%
plt.figure(figsize=(16,4))
sns.countplot(x="ownerChange", data=train_df, hue="OC").set(title='train data')
plt.show()

# %%
train_df[['OC', 'ownerChange']].groupby('ownerChange').value_counts().unstack()
# Out:
# OC            close  open
# ownerChange
# change            6    36
# same              5   242

# %%
plt.figure(figsize=(16,4))
sns.countplot(x="ownerChange", data=test_df).set(title='test data')
plt.show()

# %% [markdown]
# #### 수치형 변수 분포

# %% [markdown]
# #### 변수 간 상관관계

# %%
# %matplotlib inline
corr=train_df.drop(columns=['OC']).corr()
mask=np.triu(np.ones_like(corr, dtype=bool))[1:,:-1]
corr=corr.iloc[1:,:-1].copy()
fig, ax = plt.subplots(figsize=(48,48))   
sns.heatmap(corr, mask=mask, vmin=-1, vmax=1, center=0, annot=True, fmt='.2f', 
            cmap='coolwarm', annot_kws={'fontsize':10,'fontweight':'bold'}, cbar=False)
ax.tick_params(left=False,bottom=False)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right',fontsize=12)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=12)
plt.title('Correlations between Variables\n', fontsize=16)
fig.show()
# Out:
# C:\Users\judyj\AppData\Local\Temp\ipykernel_14388\2830312977.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
train_corr = train_df.drop(columns=['OC']).corr()
s = train_corr.unstack()
df = pd.DataFrame(s[s < 1].abs().sort_values(ascending=False), columns=['corr'])   # 상관계수의 절댓값 크기순으로 정렬
df.style.background_gradient(cmap='viridis')    # style.background_gradient : 데이터프레임에 색 입힐 수 있음.
# Out:
# <style type="text/css">
# #T_79dd5_row0_col0, #T_79dd5_row1_col0, #T_79dd5_row2_col0, #T_79dd5_row3_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_79dd5_row4_col0, #T_79dd5_row5_col0 {
#   background-color: #fbe723;
#   color: #000000;
# }
# #T_79dd5_row6_col0, #T_79dd5_row7_col0, #T_79dd5_row8_col0, #T_79dd5_row9_col0 {
#   background-color: #f6e620;
#   color: #000000;
# }
# #T_79dd5_row10_col0, #T_79dd5_row11_col0 {
#   background-color: #f4e61e;
#   color: #000000;
# }
# #T_79dd5_row12_col0, #T_79dd5_row13_col0, #T_79dd5_row14_col0, #T_79dd5_row15_col0 {
#   background-color: #f1e51d;
#   color: #000000;
# }
# #T_79dd5_row16_col0, #T_79dd5_row17_col0, #T_79dd5_row18_col0, #T_79dd5_row19_col0, #T_79dd5_row20_col0, #T_79dd5_row21_col0 {
#   background-color: #efe51c;
#   color: #000000;
# }
# ...

# %% [markdown]
# ## 3) 결측치 확인

# %%
train_df.OC.isnull().sum()
# Out:
# 0

# %% [markdown]
# - **타겟 변수(OC) 결측치 없음**

# %%
train_df.iloc[[35, 48, 62, 71, 93, 193, 206, 212, 230, 242, 263, 285, 297, 298, 299, 300],].transpose()
# Out:
#                                  35                    48                62   \
# inst_id                           58                    74                96
# OC                             close                  open              open
# sido                        gyeonggi                 seoul             busan
# sgg                              168                     1                64
# openDate                    20130206              19940425          20170602
# bedCount                       132.0                  28.0             128.0
# instkind            nursing_hospital  traditional_hospital  nursing_hospital
# revenue1                2681765580.0          8872426915.0       523640550.0
# salescost1               180200922.0           964124895.0        23067726.0
# sga1                    2014579640.0          7638919868.0       835577490.0
# salary1                  936645110.0          4488957824.0       564463637.0
# ...

# %% [markdown]
# - 많은 재무 정보 feature에 대해 0을 값으로 갖는 병원들이 보아 **자료 제공이 안 된 경우(=결측치) NaN 또는 0으로 표기되는 것으로 생각됨**. (2016년 정보는 전부 0이거나 대차대조표 정보는 전부 0 등의 형태를 보임)

# %% [markdown]
# #### train data

# %%
# 0과 NaN 모두 결측치로 보고 열별 결측치 비율 확인

train_df.replace(0, np.nan, inplace=True)

missing_col = pd.DataFrame(train_df.isnull().sum(), columns=['count'])
missing_col['rate'] = (round(missing_col['count']/len(train_df), 4)*100)
missing_col.sort_values('rate', ascending=False)
# Out:
#                     count   rate
# receivableL2          300  99.67
# receivableL1          300  99.67
# surplus2              214  71.10
# surplus1              208  69.10
# ctax2                 144  47.84
# shortLoan2            138  45.85
# ctax1                 137  45.51
# shortLoan1            130  43.19
# longLoan2             121  40.20
# salescost2            114  37.87
# longLoan1             107  35.55
# salescost1            100  33.22
# receivableS2           98  32.56
# OnonCAsset2            91  30.23
# receivableS1           82  27.24
# inventoryAsset2        76  25.25
# NCLiabilities2         73  24.25
# OnonCAsset1            73  24.25
# inventoryAsset1        65  21.59
# netAsset2              55  18.27
# NCLiabilities1         55  18.27
# debt2                  54  17.94
# tanAsset2              51  16.94
# liquidLiabilities2     51  16.94
# liquidAsset2           50  16.61
# quickAsset2            50  16.61
# nonCAsset2             50  16.61
# ...

# %% [markdown]
# - 결측치 비율에 따라 열 자체를 삭제하거나 결측치를 다른 값으로 대체하여 처리하기

# %%
# 행별 결측치 비율

trans = train_df.transpose()
missing_row = pd.DataFrame(trans.isnull().sum(), columns=['count'])
missing_row['rate'] = (round(missing_row['count']/len(trans), 4)*100)
missing_row.sort_values('rate', ascending=False).head(30)
# Out:
#      count   rate
# 258     52  89.66
# 60      51  87.93
# 14      48  82.76
# 248     48  82.76
# 1       48  82.76
# 257     48  82.76
# 55      48  82.76
# 32      48  82.76
# 230     46  79.31
# 186     44  75.86
# 297     43  74.14
# 231     42  72.41
# 47      36  62.07
# 77      35  60.34
# 193     34  58.62
# 233     34  58.62
# 266     34  58.62
# 187     34  58.62
# 215     34  58.62
# 260     33  56.90
# 288     33  56.90
# 261     33  56.90
# 35      33  56.90
# 2       32  55.17
# 262     32  55.17
# 211     32  55.17
# 280     32  55.17
# 221     32  55.17
# 222     32  55.17
# 286     31  53.45

# %% [markdown]
# - 결측치 비율 높은 행은 삭제한 데이터셋과, 결측값을 다른 값으로 대체한 데이터셋 둘 다 만들고 성능 비교하기

# %% [markdown]
# ### test data

# %%
# 열별

test_df.replace(0, np.nan, inplace=True)

missing_col1 = pd.DataFrame(test_df.isnull().sum(), columns=['count'])
missing_col1['rate'] = (round(missing_col1['count']/len(test_df), 4)*100)
missing_col1.sort_values('rate', ascending=False)
# Out:
#                     count    rate
# OC                    127  100.00
# receivableL2          126   99.21
# receivableL1          125   98.43
# surplus2               74   58.27
# surplus1               72   56.69
# ctax2                  66   51.97
# shortLoan2             59   46.46
# salescost2             51   40.16
# ctax1                  50   39.37
# shortLoan1             47   37.01
# salescost1             46   36.22
# receivableS2           39   30.71
# longLoan2              39   30.71
# inventoryAsset2        38   29.92
# OnonCAsset2            35   27.56
# inventoryAsset1        31   24.41
# NCLiabilities2         31   24.41
# receivableS1           31   24.41
# OnonCAsset1            27   21.26
# longLoan1              27   21.26
# netAsset2              25   19.69
# debt2                  24   18.90
# quickAsset2            24   18.90
# tanAsset2              23   18.11
# liquidAsset2           23   18.11
# liquidLiabilities2     23   18.11
# ...

# %% [markdown]
# ## 필요한 전처리
# - 결측치 처리
#
# - close 클래스 오버샘플링
#
# - 데이터 스케일링 (이상치 존재할 경우 이상치에 영향 많이 받는 스케일 기법은 사용하지 말 것.)
#
# - 변수생성 ex) 지급능력(유동자산 - 유동부채) 등 주요 재무 정보
#  > 주요 재무지표: https://www.kospo.co.kr/kospo/299/subview.do
#
# - 두 개념을 포괄하는 개념이 있으면 상관관계 고려해 적절히 선택.  (+ bedcount나 instkind 중에도 취사선택?)
#
# - 시/도 범주 축소 (묶기)
#
# - open_date 는 pd.to_datetime 써서 시간으로 바꿔주기
#
# - astype으로 문자범주형 -> 숫자로 바꿔주기, 원핫인코딩, bedcount는 pd.qcut?
#
# - 시/도는 신경망모델 돌릴 때만 숫자형으로 바꾸기
